# %%
import pyodbc
import pandas as pd
import ollama

# Connection details
server = 'syn-edw-eus.sql.azuresynapse.net'
database = 'syndpedweus'
username = 'SantoshKumar.Sirasapalli@UHhospitals.org'
password = 'HelloSun@123'
# MFA Interactive connection string
connection_string = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={server};
DATABASE={database};
UID={username};
Authentication=ActiveDirectoryInteractive;
"""

# Step 1: Connect and query data
try:
    print("Connecting to database...")
    conn = pyodbc.connect(connection_string, autocommit=True)
    print("Connected successfully!")

    query = """
    SELECT TOP 100 *
    FROM caboodle.patientdim;
    """

    print("Running query...")
    df = pd.read_sql(query, conn)

    print("\n--- QUERY RESULTS ---")
    print(df)

except Exception as e:
    print("Error:", e)

finally:
    try:
        conn.close()
        print("\nConnection closed.")
    except:
        pass
# Out:
# Connecting to database...
# Connected successfully!
# Running query...
# C:\Users\UH246070SHARED\AppData\Local\Temp\ipykernel_32088\1050211020.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# --- QUERY RESULTS ---
#                                            ETLKeyHash  \
# 0   ece4c0bacbe839468482a08757e07beb089cd2a441c607...
# 1   6468cfa611a5b2daec1c8cfa4e16c03d1be84d204031a3...
# 2   6aa7005913f6e5a66d562ed93f42ffc57a2296dec764ce...
# 3   b2e9e7c779deea5ed6e45fdac93fecdac2b31940b24fdf...
# 4   6f7b11c13a2bcac292aa13625c559d5e78c91a415f7177...
# ..                                                ...
# 95  a8efde13babd3b175c96a8920c9729fda66d6b925a657a...
# 96  0c43a2aaf2fa79f921a8705d7fa4aceb159ec4a4bdf3f8...
# 97  3e273b4061b891d69c747eb13a32d70162f8cb9ccd4cd0...
# ...

# %%
import pyodbc
import pandas as pd
import ollama

# Connection details
server = 'sss'
database = 'sss'
username = 'sss'
password = 'sss'
# MFA Interactive connection string
connection_string = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={server};
DATABASE={database};
UID={username};
Authentication=ActiveDirectoryInteractive;
"""

# Step 1: Connect and query data
try:
    print("Connecting to database...")
    conn = pyodbc.connect(connection_string, autocommit=True)
    print("Connected successfully!")

    query = """
    SELECT TOP 100 *
    FROM caboodle.patientdim;
    """

    print("Running query...")
    df = pd.read_sql(query, conn)

    print("\n--- QUERY RESULTS ---")
    print(df)

except Exception as e:
    print("Error:", e)

finally:
    try:
        conn.close()
        print("\nConnection closed.")
    except:
        pass
